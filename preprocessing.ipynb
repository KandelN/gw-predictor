# %% [markdown]
# ### Loading necessary packages and preparing kernel.

# %%
import pandas as pd

# %% [markdown]
# ### Reading data
# Shortned version of data file is used for github sharing. Complete data file can be provided when requested.

# %%
data = pd.read_excel('data\DeepTubeWell_Data-SAMPLE.xlsx', sheet_name = 'Sheet1')
data.head()
# Out:
#    well_id            well          Y         X        Y_UTM        X_UTM
# 0        3  BalajuPark Well  27.73411  85.30196  3068903.385  332622.4245  \
# 1        3  BalajuPark Well  27.73411  85.30196  3068903.385  332622.4245
# 2        3  BalajuPark Well  27.73411  85.30196  3068903.385  332622.4245
# 3        3  BalajuPark Well  27.73411  85.30196  3068903.385  332622.4245
# 4        3  BalajuPark Well  27.73411  85.30196  3068903.385  332622.4245
#
#                                Material  Top Elevation  Thickness
# 0                              Top Soil         1311.0        0.5  \
# 1                        Weathered Soil         1310.5        4.5
# 2                    Colluvium Deposite         1306.0       60.0
# 3  Highly saturated fractured limestone         1246.0       80.0
# 4         Partially Saturated Limestone         1166.0       15.0
#
#    Bottom Elevation  ...  Well Size (mm)  Q_lpm  permiability_cm/s
# ...

# %% [markdown]
# ### Extracting first row of every well.

# %%
# data['well_id'].unique()

# %%
screened_data = pd.DataFrame()
for id in data['well_id'].unique():
    screened_data = pd.concat([screened_data, data[data['well_id'] == id].iloc[:1, :] ])

screened_data.head()
# Out:
#     well_id                          well           Y          X        Y_UTM
# 0         3                BalajuPark Well  27.734110  85.301960  3068903.385  \
# 6        26  Budhanilkantha Deep Tube Well  27.787778  85.369108  3074760.086
# 9         1                   Airport well  27.675980  85.351300  3062396.646
# 10        2                    Bahiti well  27.707290  85.285330  3065954.486
# 11        4                 Balkumari Well  27.670640  85.337830  3061822.828
#
#           X_UTM           Material  Top Elevation  Thickness
# 0   332622.4245           Top Soil         1311.0        0.5  \
# 6   339321.2053  Clayey silty sand         1587.0       22.0
# 9   337400.5100                NaN            NaN        NaN
# 10  330941.5302                NaN            NaN        NaN
# 11  336063.8739                NaN            NaN        NaN
#
#     Bottom Elevation  ...  Well Size (mm)  Q_lpm  permiability_cm/s
# ...

# %% [markdown]
# ### Filtering out rows containing no discharge values.

# %%
screened_data = screened_data[screened_data['Q_lpm'].notna()]
screened_data.head()
# Out:
#     well_id                          well           Y          X        Y_UTM
# 0         3                BalajuPark Well  27.734110  85.301960  3068903.385  \
# 6        26  Budhanilkantha Deep Tube Well  27.787778  85.369108  3074760.086
# 9         1                   Airport well  27.675980  85.351300  3062396.646
# 10        2                    Bahiti well  27.707290  85.285330  3065954.486
# 11        4                 Balkumari Well  27.670640  85.337830  3061822.828
#
#           X_UTM           Material  Top Elevation  Thickness
# 0   332622.4245           Top Soil         1311.0        0.5  \
# 6   339321.2053  Clayey silty sand         1587.0       22.0
# 9   337400.5100                NaN            NaN        NaN
# 10  330941.5302                NaN            NaN        NaN
# 11  336063.8739                NaN            NaN        NaN
#
#     Bottom Elevation  ...  Well Size (mm)  Q_lpm  permiability_cm/s
# ...

# %% [markdown]
# ### Creating a new dataframe with only necessary columns for discharge modeling

# %%
qdata = screened_data.reset_index()[['well ','X_UTM','Y_UTM', 'Q_lpm']]
qdata
# Out:
#                            well         X_UTM        Y_UTM  Q_lpm
# 0                BalajuPark Well  332622.4245  3068903.385  600.0
# 1  Budhanilkantha Deep Tube Well  339321.2053  3074760.086  480.0
# 2                   Airport well  337400.5100  3062396.646  700.0
# 3                    Bahiti well  330941.5302  3065954.486  300.0
# 4                 Balkumari Well  336063.8739  3061822.828  350.0

# %% [markdown]
# ### Save new dataframe

# %%
# qdata.to_csv('data\cleaned-qdata.csv', index =False)
qdata.to_csv('data\cleaned-qdata-SAMPLE.csv', index =False)

# Saving disabled to overwrite existing file.

# %% [markdown]
# ---
